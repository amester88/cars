# %%
import pandas as pd 
import numpy as np
import os
from os import listdir # for directories 
import cv2 # resizing images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image as PImage
import collections
import re
from random import shuffle
from tqdm import tqdm # percentage bar for task completion 
from tensorflow.keras import datasets, layers, models
import tensorflow.compat.v2 as tf

# %%
##filename = "/Users/annemester/Downloads/"
train = "/Users/annemester/Downloads/cars/cars_train"
test = "/Users/annemester/Downloads/cars/cars_test"
image_size = 50
lr = 1e-3
model_nm = 'cars-{}-{}.model'.format(lr, '2conv-basic')
####test_data = image.imread('Users/annemester/Downloads/cars_test')
###load_data(train_data)

# %%
def image_label(image_name):
  label = image_name.split('.')[0]
  print(image_name.split('.'))
  image = train
  # converts to one-hot array

# %%
def create_train_data():
    train_data = []
    for image_name in tqdm(os.listdir(train)):
        image2 = os.listdir(train)
        ind_label = image_label(image_name)
        path = os.path.join(train, image_name)
        image = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
        image_name = np.array(image_name)
        image = cv2.resize(image, (image_size,image_size))
        image2.append([np.array(image), image_name])
    shuffle(train_data)
    np.save('train.npy', train)
    return train_data
# Out:
# 'jpg']
# ['03346', 'jpg']
# ['04429', 'jpg']
# ['07108', 'jpg']
# ['00667', 'jpg']
# ['01579', 'jpg']
# ['06216', 'jpg']
# ['02070', 'jpg']
# ['04401', 'jpg']
# ['04367', 'jpg']
# ['03408', 'jpg']
# ['02716', 'jpg']
#  88%|████████▊ | 7181/8144 [01:33<00:13, 73.09it/s]['05079', 'jpg']
# ['06570', 'jpg']
# ['00101', 'jpg']
# ['06564', 'jpg']
# ['00115', 'jpg']
# ['04373', 'jpg']
# ['02702', 'jpg']
# ['02064', 'jpg']
# ['04415', 'jpg']
# ['00673', 'jpg']
# ['06202', 'jpg']
# ['01586', 'jpg']
# ['00840', 'jpg']
# ['00698', 'jpg']
# ['05938', 'jpg']
# ['03391', 'jpg']
# ['05086', 'jpg']
#  88%|████████▊ | 7189/8144 [01:33<00:15, 61.22it/s]['04398', 'jpg']
# ['02931', 'jpg']
# ['07691', 'jpg']
# ['07849', 'jpg']
# ['07685', 'jpg']
# ['05092', 'jpg']
# ['02925', 'jpg']
# ['03385', 'jpg']
# ['01592', 'jpg']
# ['00854', 'jpg']
# ['05904', 'jpg']
#  88%|████████▊ | 7206/8144 [01:33<00:13, 70.12it/s]['07875', 'jpg']
# ['02919', 'jpg']
# ['07861', 'jpg']
# ['00868', 'jpg']
# ['05910', 'jpg']
# ['05247', 'jpg']
# ['02528', 'jpg']
# ['03636', 'jpg']
# ['04159', 'jpg']
# ['07450', 'jpg']
# ['06996', 'jpg']
# ['01021', 'jpg']
# ['06028', 'jpg']
# ['01747', 'jpg']
# ['00459', 'jpg']
# ['07336', 'jpg']
# ['08005', 'jpg']
#  89%|████████▊ | 7224/8144 [01:33<00:11, 76.82it/s]['03150', 'jpg']
# ['05521', 'jpg']
# ['03144', 'jpg']
# ['05535', 'jpg']
# ['01753', 'jpg']
# ['07322', 'jpg']
# ['08011', 'jpg']
# ['07444', 'jpg']
# ['06982', 'jpg']
# ['01035', 'jpg']
# ['05253', 'jpg']
# ['03622', 'jpg']
# ['00303', 'jpg']
# ['06772', 'jpg']
# ['02514', 'jpg']
# ['04165', 'jpg']
# ['04603', 'jpg']
#  89%|████████▉ | 7240/8144 [01:34<00:11, 75.51it/s]['02272', 'jpg']
# ['06014', 'jpg']
# ['00465', 'jpg']
# ['08039', 'jpg']
# ['06000', 'jpg']
# ['00471', 'jpg']
# ['04617', 'jpg']
# ['03178', 'jpg']
# ['02266', 'jpg']
# ['05509', 'jpg']
# ['02500', 'jpg']
# ['04171', 'jpg']
# ['07478', 'jpg']
# ['00317', 'jpg']
# ['01009', 'jpg']
# ['06766', 'jpg']
#  89%|████████▉ | 7257/8144 [01:34<00:11, 77.45it/s]['07493', 'jpg']
# ['06955', 'jpg']
# ['05284', 'jpg']
# ['04824', 'jpg']
# ['03193', 'jpg']
# ['01784', 'jpg']
# ['01948', 'jpg']
# ['01790', 'jpg']
# ['02299', 'jpg']
# ['04830', 'jpg']
# ['03187', 'jpg']
# ['03839', 'jpg']
# ['05290', 'jpg']
# ['06799', 'jpg']
# ['07487', 'jpg']
# ['06941', 'jpg']
#  89%|████████▉ | 7265/8144 [01:34<00:11, 74.23it/s]['03811', 'jpg']
# ['06969', 'jpg']
# ['01960', 'jpg']
# ['04818', 'jpg']
# ['01974', 'jpg']
# ['03805', 'jpg']
# ['03742', 'jpg']
# ['05333', 'jpg']
# ['01155', 'jpg']
# ['07524', 'jpg']
# ['07242', 'jpg']
# ['01633', 'jpg']
# ['05455', 'jpg']
#  89%|████████▉ | 7282/8144 [01:34<00:12, 71.81it/s]['04993', 'jpg']
# ['03024', 'jpg']
# ['05441', 'jpg']
# ['04987', 'jpg']
# ['03030', 'jpg']
# ['07256', 'jpg']
# ['00539', 'jpg']
# ['01627', 'jpg']
# ['06148', 'jpg']
# ['01141', 'jpg']
# ['07530', 'jpg']
# ['04039', 'jpg']
# ['03756', 'jpg']
# ['02448', 'jpg']
# ['05327', 'jpg']
# ['06606', 'jpg']
# ['01169', 'jpg']
#  90%|████████▉ | 7298/8144 [01:34<00:11, 71.91it/s]['00277', 'jpg']
# ['07518', 'jpg']
# ['04011', 'jpg']
# ['02460', 'jpg']
# ['05469', 'jpg']
# ['02306', 'jpg']
# ['03018', 'jpg']
# ['04777', 'jpg']
# ['00511', 'jpg']
# ['06160', 'jpg']
# ['00505', 'jpg']
# ['06174', 'jpg']
# ['02312', 'jpg']
# ['04763', 'jpg']
# ['04005', 'jpg']
#  90%|████████▉ | 7315/8144 [01:35<00:11, 74.40it/s]['02474', 'jpg']
# ['06612', 'jpg']
# ['00263', 'jpg']
# ['06821', 'jpg']
# ['00288', 'jpg']
# ['01196', 'jpg']
# ['03959', 'jpg']
# ['03781', 'jpg']
# ['04788', 'jpg']
# ['05496', 'jpg']
# ['04950', 'jpg']
# ['07281', 'jpg']
# ['01828', 'jpg']
# ['07295', 'jpg']
# ['05482', 'jpg']
#  90%|█████████ | 7331/8144 [01:35<00:11, 73.49it/s]['04944', 'jpg']
# ['03795', 'jpg']
# ['06835', 'jpg']
# ['01182', 'jpg']
# ['03965', 'jpg']
# ['01814', 'jpg']
# ['04978', 'jpg']
# ['01800', 'jpg']
# ['06809', 'jpg']
# ['03971', 'jpg']
# ['04549', 'jpg']
# ['03226', 'jpg']
# ['02138', 'jpg']
# ['05657', 'jpg']
# ['01431', 'jpg']
# ['07040', 'jpg']
# ['07726', 'jpg']
#  90%|█████████ | 7348/8144 [01:35<00:10, 78.71it/s]['00049', 'jpg']
# ['01357', 'jpg']
# ['06438', 'jpg']
# ['05131', 'jpg']
# ['03540', 'jpg']
# ['02886', 'jpg']
# ['05125', 'jpg']
# ['03554', 'jpg']
# ['02892', 'jpg']
# ['07732', 'jpg']
# ['01343', 'jpg']
# ['01425', 'jpg']
# ['07054', 'jpg']
# ['03232', 'jpg']
# ['05643', 'jpg']
# ['06362', 'jpg']
# ['00713', 'jpg']
#  90%|█████████ | 7365/8144 [01:35<00:09, 81.66it/s]['04575', 'jpg']
# ['02104', 'jpg']
# ['02662', 'jpg']
# ['04213', 'jpg']
# ['00075', 'jpg']
# ['06404', 'jpg']
# ['00061', 'jpg']
# ['06410', 'jpg']
# ['05119', 'jpg']
# ['02676', 'jpg']
# ['03568', 'jpg']
# ['04207', 'jpg']
# ['04561', 'jpg']
# ['02110', 'jpg']
# ['06376', 'jpg']
# ['01419', 'jpg']
# ['00707', 'jpg']
# ['07068', 'jpg']
#  91%|█████████ | 7383/8144 [01:35<00:09, 83.30it/s]['07083', 'jpg']
# ['00934', 'jpg']
# ['05694', 'jpg']
# ['03583', 'jpg']
# ['02845', 'jpg']
# ['01394', 'jpg']
# ['01380', 'jpg']
# ['07929', 'jpg']
# ['03597', 'jpg']
# ['02851', 'jpg']
# ['02689', 'jpg']
# ['05680', 'jpg']
# ['05858', 'jpg']
# ['07097', 'jpg']
# ['00920', 'jpg']
# ['06389', 'jpg']
#  91%|█████████ | 7400/8144 [01:36<00:09, 76.95it/s]['05870', 'jpg']
# ['00908', 'jpg']
# ['07901', 'jpg']
# ['02879', 'jpg']
# ['07915', 'jpg']
# ['05864', 'jpg']
# ['07914', 'jpg']
# ['05865', 'jpg']
# ['00909', 'jpg']
# ['05871', 'jpg']
# ['02878', 'jpg']
# ['07900', 'jpg']
# ['02688', 'jpg']
# ['02850', 'jpg']
# ['03596', 'jpg']
#  91%|█████████ | 7416/8144 [01:36<00:09, 77.87it/s]['07928', 'jpg']
# ['01381', 'jpg']
# ['06388', 'jpg']
# ['00921', 'jpg']
# ['07096', 'jpg']
# ['05859', 'jpg']
# ['05681', 'jpg']
# ['05695', 'jpg']
# ['00935', 'jpg']
# ['07082', 'jpg']
# ['01395', 'jpg']
# ['02844', 'jpg']
# ['03582', 'jpg']
# ['04206', 'jpg']
# ['03569', 'jpg']
# ['02677', 'jpg']
# ['05118', 'jpg']
#  91%|█████████▏| 7435/8144 [01:36<00:08, 81.81it/s]['06411', 'jpg']
# ['00060', 'jpg']
# ['07069', 'jpg']
# ['00706', 'jpg']
# ['01418', 'jpg']
# ['06377', 'jpg']
# ['02111', 'jpg']
# ['04560', 'jpg']
# ['02105', 'jpg']
# ['04574', 'jpg']
# ['00712', 'jpg']
# ['06363', 'jpg']
# ['06405', 'jpg']
# ['00074', 'jpg']
# ['04212', 'jpg']
# ['02663', 'jpg']
# ['01342', 'jpg']
# ['07733', 'jpg']
#  92%|█████████▏| 7453/8144 [01:36<00:08, 83.96it/s]['02893', 'jpg']
# ['03555', 'jpg']
# ['05124', 'jpg']
# ['05642', 'jpg']
# ['03233', 'jpg']
# ['07055', 'jpg']
# ['01424', 'jpg']
# ['07041', 'jpg']
# ['01430', 'jpg']
# ['05656', 'jpg']
# ['02139', 'jpg']
# ['03227', 'jpg']
# ['04548', 'jpg']
# ['02887', 'jpg']
# ['03541', 'jpg']
# ['05130', 'jpg']
# ['06439', 'jpg']
# ['01356', 'jpg']
#  92%|█████████▏| 7462/8144 [01:36<00:08, 81.97it/s]['00048', 'jpg']
# ['07727', 'jpg']
# ['01801', 'jpg']
# ['04979', 'jpg']
# ['03970', 'jpg']
# ['06808', 'jpg']
# ['03964', 'jpg']
# ['01815', 'jpg']
# ['04945', 'jpg']
# ['05483', 'jpg']
# ['07294', 'jpg']
# ['01183', 'jpg']
# ['06834', 'jpg']
# ['03794', 'jpg']
#  92%|█████████▏| 7480/8144 [01:37<00:08, 75.02it/s]['03780', 'jpg']
# ['03958', 'jpg']
# ['01197', 'jpg']
# ['00289', 'jpg']
# ['06820', 'jpg']
# ['01829', 'jpg']
# ['07280', 'jpg']
# ['04951', 'jpg']
# ['05497', 'jpg']
# ['04789', 'jpg']
# ['04762', 'jpg']
# ['02313', 'jpg']
# ['06175', 'jpg']
# ['00504', 'jpg']
# ['00262', 'jpg']
# ['06613', 'jpg']
# ['02475', 'jpg']
#  92%|█████████▏| 7496/8144 [01:37<00:09, 71.76it/s]['04004', 'jpg']
# ['02461', 'jpg']
# ['04010', 'jpg']
# ['07519', 'jpg']
# ['00276', 'jpg']
# ['01168', 'jpg']
# ['06607', 'jpg']
# ['06161', 'jpg']
# ['00510', 'jpg']
# ['04776', 'jpg']
# ['03019', 'jpg']
# ['02307', 'jpg']
# ['05468', 'jpg']
# ['06149', 'jpg']
# ['01626', 'jpg']
#  92%|█████████▏| 7513/8144 [01:37<00:08, 76.41it/s]['00538', 'jpg']
# ['07257', 'jpg']
# ['03031', 'jpg']
# ['04986', 'jpg']
# ['05440', 'jpg']
# ['05326', 'jpg']
# ['02449', 'jpg']
# ['03757', 'jpg']
# ['04038', 'jpg']
# ['07531', 'jpg']
# ['01140', 'jpg']
# ['07525', 'jpg']
# ['01154', 'jpg']
# ['05332', 'jpg']
# ['03743', 'jpg']
# ['03025', 'jpg']
# ['04992', 'jpg']
#  92%|█████████▏| 7531/8144 [01:37<00:08, 75.29it/s]['05454', 'jpg']
# ['01632', 'jpg']
# ['07243', 'jpg']
# ['01975', 'jpg']
# ['03804', 'jpg']
# ['06968', 'jpg']
# ['03810', 'jpg']
# ['04819', 'jpg']
# ['01961', 'jpg']
# ['03186', 'jpg']
# ['04831', 'jpg']
# ['02298', 'jpg']
# ['01791', 'jpg']
# ['01949', 'jpg']
# ['06940', 'jpg']
#  93%|█████████▎| 7540/8144 [01:37<00:07, 76.75it/s]['07486', 'jpg']
# ['06798', 'jpg']
# ['05291', 'jpg']
# ['03838', 'jpg']
# ['05285', 'jpg']
# ['06954', 'jpg']
# ['07492', 'jpg']
# ['01785', 'jpg']
# ['03192', 'jpg']
# ['04825', 'jpg']
# ['05508', 'jpg']
# ['02267', 'jpg']
# ['03179', 'jpg']
# ['04616', 'jpg']
#  93%|█████████▎| 7557/8144 [01:38<00:07, 76.48it/s]['00470', 'jpg']
# ['06001', 'jpg']
# ['06767', 'jpg']
# ['01008', 'jpg']
# ['00316', 'jpg']
# ['07479', 'jpg']
# ['04170', 'jpg']
# ['02501', 'jpg']
# ['04164', 'jpg']
# ['02515', 'jpg']
# ['06773', 'jpg']
# ['00302', 'jpg']
# ['08038', 'jpg']
# ['00464', 'jpg']
# ['06015', 'jpg']
# ['02273', 'jpg']
# ['04602', 'jpg']
# ['08010', 'jpg']
#  93%|█████████▎| 7575/8144 [01:38<00:07, 78.21it/s]['07323', 'jpg']
# ['01752', 'jpg']
# ['05534', 'jpg']
# ['03145', 'jpg']
# ['03623', 'jpg']
# ['05252', 'jpg']
# ['01034', 'jpg']
# ['06983', 'jpg']
# ['07445', 'jpg']
# ['01020', 'jpg']
# ['06997', 'jpg']
# ['07451', 'jpg']
# ['04158', 'jpg']
# ['03637', 'jpg']
# ['02529', 'jpg']
# ['05246', 'jpg']
#  93%|█████████▎| 7593/8144 [01:38<00:06, 81.38it/s]['05520', 'jpg']
# ['03151', 'jpg']
# ['08004', 'jpg']
# ['07337', 'jpg']
# ['00458', 'jpg']
# ['01746', 'jpg']
# ['06029', 'jpg']
# ['07860', 'jpg']
# ['02918', 'jpg']
# ['05911', 'jpg']
# ['00869', 'jpg']
# ['05905', 'jpg']
# ['07874', 'jpg']
# ['02924', 'jpg']
# ['05093', 'jpg']
# ['07684', 'jpg']
# ['00855', 'jpg']
# ['01593', 'jpg']
#  93%|█████████▎| 7611/8144 [01:38<00:07, 71.89it/s]['03384', 'jpg']
# ['03390', 'jpg']
# ['05939', 'jpg']
# ['00699', 'jpg']
# ['00841', 'jpg']
# ['01587', 'jpg']
# ['07848', 'jpg']
# ['07690', 'jpg']
# ['02930', 'jpg']
# ['04399', 'jpg']
# ['05087', 'jpg']
# ['02703', 'jpg']
# ['04372', 'jpg']
#  94%|█████████▎| 7628/8144 [01:39<00:06, 76.12it/s]['00114', 'jpg']
# ['06565', 'jpg']
# ['06203', 'jpg']
# ['00672', 'jpg']
# ['04414', 'jpg']
# ['02065', 'jpg']
# ['04400', 'jpg']
# ['02071', 'jpg']
# ['06217', 'jpg']
# ['01578', 'jpg']
# ['00666', 'jpg']
# ['07109', 'jpg']
# ['00100', 'jpg']
# ['06571', 'jpg']
# ['05078', 'jpg']
# ['02717', 'jpg']
# ['03409', 'jpg']
#  94%|█████████▍| 7644/8144 [01:39<00:06, 73.82it/s]['04366', 'jpg']
# ['07647', 'jpg']
# ['00128', 'jpg']
# ['01236', 'jpg']
# ['06559', 'jpg']
# ['05050', 'jpg']
# ['03421', 'jpg']
# ['04428', 'jpg']
# ['03347', 'jpg']
# ['02059', 'jpg']
# ['05736', 'jpg']
# ['00896', 'jpg']
# ['01550', 'jpg']
# ['07121', 'jpg']
# ['00882', 'jpg']
#  94%|█████████▍| 7653/8144 [01:39<00:06, 76.97it/s]['01544', 'jpg']
# ['07135', 'jpg']
# ['03353', 'jpg']
# ['05722', 'jpg']
# ['05044', 'jpg']
# ['03435', 'jpg']
# ['07653', 'jpg']
# ['01222', 'jpg']
# ['07123', 'jpg']
# ['01552', 'jpg']
# ['00894', 'jpg']
# ['05734', 'jpg']
# ['03345', 'jpg']
# ['03423', 'jpg']
# ['05052', 'jpg']
# ['01234', 'jpg']
# ['07645', 'jpg']
#  94%|█████████▍| 7669/8144 [01:39<00:06, 74.89it/s]['07889', 'jpg']
# ['01220', 'jpg']
# ['07651', 'jpg']
# ['04358', 'jpg']
# ['03437', 'jpg']
# ['02729', 'jpg']
# ['05046', 'jpg']
# ['05720', 'jpg']
# ['03351', 'jpg']
# ['07137', 'jpg']
# ['00658', 'jpg']
# ['01546', 'jpg']
# ['06229', 'jpg']
# ['00880', 'jpg']
# ['05708', 'jpg']
#  94%|█████████▍| 7686/8144 [01:39<00:06, 74.26it/s]['02067', 'jpg']
# ['03379', 'jpg']
# ['04416', 'jpg']
# ['00670', 'jpg']
# ['06201', 'jpg']
# ['06567', 'jpg']
# ['01208', 'jpg']
# ['00116', 'jpg']
# ['07679', 'jpg']
# ['04370', 'jpg']
# ['02701', 'jpg']
# ['04364', 'jpg']
# ['02715', 'jpg']
# ['06573', 'jpg']
#  95%|█████████▍| 7703/8144 [01:40<00:06, 71.24it/s]['00102', 'jpg']
# ['00664', 'jpg']
# ['06215', 'jpg']
# ['02073', 'jpg']
# ['04402', 'jpg']
# ['03386', 'jpg']
# ['02098', 'jpg']
# ['01591', 'jpg']
# ['00857', 'jpg']
# ['07686', 'jpg']
# ['06598', 'jpg']
# ['05091', 'jpg']
# ['02926', 'jpg']
# ['05085', 'jpg']
# ['02932', 'jpg']
# ['07692', 'jpg']
#  95%|█████████▍| 7720/8144 [01:40<00:05, 75.92it/s]['01585', 'jpg']
# ['00843', 'jpg']
# ['03392', 'jpg']
# ['05913', 'jpg']
# ['07862', 'jpg']
# ['07876', 'jpg']
# ['05907', 'jpg']
# ['07447', 'jpg']
# ['00328', 'jpg']
# ['06981', 'jpg']
# ['01036', 'jpg']
# ['06759', 'jpg']
# ['05250', 'jpg']
# ['03621', 'jpg']
# ['04628', 'jpg']
# ['03147', 'jpg']
#  95%|█████████▌| 7737/8144 [01:40<00:05, 78.48it/s]['02259', 'jpg']
# ['05536', 'jpg']
# ['01750', 'jpg']
# ['08012', 'jpg']
# ['01988', 'jpg']
# ['07321', 'jpg']
# ['01744', 'jpg']
# ['08006', 'jpg']
# ['07335', 'jpg']
# ['03153', 'jpg']
# ['05522', 'jpg']
# ['05244', 'jpg']
# ['03635', 'jpg']
# ['07453', 'jpg']
# ['06995', 'jpg']
# ['01022', 'jpg']
# ['02503', 'jpg']
#  95%|█████████▌| 7754/8144 [01:40<00:04, 78.84it/s]['04172', 'jpg']
# ['00314', 'jpg']
# ['06765', 'jpg']
# ['06003', 'jpg']
# ['00472', 'jpg']
# ['04614', 'jpg']
# ['02265', 'jpg']
# ['04600', 'jpg']
# ['02271', 'jpg']
# ['06017', 'jpg']
# ['01778', 'jpg']
# ['00466', 'jpg']
# ['07309', 'jpg']
# ['00300', 'jpg']
# ['06771', 'jpg']
# ['05278', 'jpg']
#  95%|█████████▌| 7772/8144 [01:40<00:04, 83.73it/s]['02517', 'jpg']
# ['03609', 'jpg']
# ['04166', 'jpg']
# ['05293', 'jpg']
# ['07484', 'jpg']
# ['06942', 'jpg']
# ['01793', 'jpg']
# ['04833', 'jpg']
# ['03184', 'jpg']
# ['04827', 'jpg']
# ['03190', 'jpg']
# ['00499', 'jpg']
# ['01787', 'jpg']
# ['07490', 'jpg']
# ['06956', 'jpg']
# ['04199', 'jpg']
# ['05287', 'jpg']
# ['03806', 'jpg']
#  96%|█████████▌| 7790/8144 [01:41<00:04, 82.12it/s]['01977', 'jpg']
# ['01963', 'jpg']
# ['03812', 'jpg']
# ['01142', 'jpg']
# ['07533', 'jpg']
# ['03755', 'jpg']
# ['05324', 'jpg']
# ['05442', 'jpg']
# ['04984', 'jpg']
# ['03033', 'jpg']
# ['07255', 'jpg']
# ['01624', 'jpg']
# ['07241', 'jpg']
# ['01630', 'jpg']
# ['05456', 'jpg']
# ['04990', 'jpg']
# ['02339', 'jpg']
#  96%|█████████▌| 7799/8144 [01:41<00:04, 79.45it/s]['03027', 'jpg']
# ['04748', 'jpg']
# ['03741', 'jpg']
# ['05330', 'jpg']
# ['03999', 'jpg']
# ['06639', 'jpg']
# ['01156', 'jpg']
# ['00248', 'jpg']
# ['07527', 'jpg']
# ['04006', 'jpg']
# ['03769', 'jpg']
# ['02477', 'jpg']
# ['05318', 'jpg']
# ['06611', 'jpg']
#  96%|█████████▌| 7815/8144 [01:41<00:04, 74.28it/s]['00260', 'jpg']
# ['07269', 'jpg']
# ['00506', 'jpg']
# ['01618', 'jpg']
# ['06177', 'jpg']
# ['02311', 'jpg']
# ['04760', 'jpg']
# ['02305', 'jpg']
# ['04774', 'jpg']
# ['00512', 'jpg']
# ['06163', 'jpg']
# ['06605', 'jpg']
# ['00274', 'jpg']
# ['04012', 'jpg']
# ['02463', 'jpg']
# ['02488', 'jpg']
#  96%|█████████▌| 7832/8144 [01:41<00:04, 76.89it/s]['03796', 'jpg']
# ['06836', 'jpg']
# ['01181', 'jpg']
# ['06188', 'jpg']
# ['07296', 'jpg']
# ['05481', 'jpg']
# ['04947', 'jpg']
# ['05495', 'jpg']
# ['04953', 'jpg']
# ['07282', 'jpg']
# ['06822', 'jpg']
# ['01195', 'jpg']
# ['03782', 'jpg']
# ['03972', 'jpg']
# ['01803', 'jpg']
# ['01817', 'jpg']
#  96%|█████████▋| 7851/8144 [01:42<00:03, 78.28it/s]['03966', 'jpg']
# ['06349', 'jpg']
# ['01426', 'jpg']
# ['00738', 'jpg']
# ['07057', 'jpg']
# ['03231', 'jpg']
# ['05898', 'jpg']
# ['05640', 'jpg']
# ['05126', 'jpg']
# ['02649', 'jpg']
# ['03557', 'jpg']
# ['02891', 'jpg']
# ['04238', 'jpg']
# ['07731', 'jpg']
# ['01340', 'jpg']
# ['07725', 'jpg']
#  97%|█████████▋| 7867/8144 [01:42<00:03, 78.72it/s]['01354', 'jpg']
# ['05132', 'jpg']
# ['03543', 'jpg']
# ['02885', 'jpg']
# ['03225', 'jpg']
# ['05654', 'jpg']
# ['01432', 'jpg']
# ['07043', 'jpg']
# ['04562', 'jpg']
# ['02113', 'jpg']
# ['06375', 'jpg']
# ['00704', 'jpg']
# ['00062', 'jpg']
# ['06413', 'jpg']
# ['02675', 'jpg']
# ['04204', 'jpg']
#  97%|█████████▋| 7876/8144 [01:42<00:03, 80.69it/s]['02661', 'jpg']
# ['04210', 'jpg']
# ['07719', 'jpg']
# ['00076', 'jpg']
# ['01368', 'jpg']
# ['06407', 'jpg']
# ['06361', 'jpg']
# ['00710', 'jpg']
# ['04576', 'jpg']
# ['03219', 'jpg']
# ['02107', 'jpg']
# ['05668', 'jpg']
#  97%|█████████▋| 7893/8144 [01:42<00:03, 69.55it/s]['05683', 'jpg']
# ['07094', 'jpg']
# ['00923', 'jpg']
# ['01383', 'jpg']
# ['03594', 'jpg']
# ['02852', 'jpg']
# ['03580', 'jpg']
# ['02846', 'jpg']
# ['01397', 'jpg']
# ['00089', 'jpg']
# ['07080', 'jpg']
# ['00937', 'jpg']
# ['05697', 'jpg']
# ['04589', 'jpg']
# ['05867', 'jpg']
# ['07916', 'jpg']
#  97%|█████████▋| 7909/8144 [01:42<00:03, 70.60it/s]['07902', 'jpg']
# ['05873', 'jpg']
# ['07903', 'jpg']
# ['05872', 'jpg']
# ['05866', 'jpg']
# ['07917', 'jpg']
# ['00088', 'jpg']
# ['01396', 'jpg']
# ['02847', 'jpg']
# ['03581', 'jpg']
# ['04588', 'jpg']
# ['05696', 'jpg']
# ['00936', 'jpg']
# ['07081', 'jpg']
# ['00922', 'jpg']
#  97%|█████████▋| 7917/8144 [01:42<00:03, 70.66it/s]['07095', 'jpg']
# ['05682', 'jpg']
# ['02853', 'jpg']
# ['03595', 'jpg']
# ['01382', 'jpg']
# ['06406', 'jpg']
# ['01369', 'jpg']
# ['00077', 'jpg']
# ['07718', 'jpg']
# ['04211', 'jpg']
# ['02660', 'jpg']
#  97%|█████████▋| 7935/8144 [01:43<00:03, 69.09it/s]['05669', 'jpg']
# ['02106', 'jpg']
# ['03218', 'jpg']
# ['04577', 'jpg']
# ['00711', 'jpg']
# ['06360', 'jpg']
# ['00705', 'jpg']
# ['06374', 'jpg']
# ['02112', 'jpg']
# ['04563', 'jpg']
# ['04205', 'jpg']
# ['02674', 'jpg']
# ['06412', 'jpg']
# ['00063', 'jpg']
# ['02884', 'jpg']
# ['03542', 'jpg']
# ['05133', 'jpg']
# ['01355', 'jpg']
#  98%|█████████▊| 7944/8144 [01:43<00:02, 74.12it/s]['07724', 'jpg']
# ['07042', 'jpg']
# ['01433', 'jpg']
# ['05655', 'jpg']
# ['03224', 'jpg']
# ['05641', 'jpg']
# ['05899', 'jpg']
# ['03230', 'jpg']
# ['07056', 'jpg']
# ['00739', 'jpg']
# ['01427', 'jpg']
#  98%|█████████▊| 7962/8144 [01:43<00:03, 56.16it/s]['06348', 'jpg']
# ['01341', 'jpg']
# ['07730', 'jpg']
# ['04239', 'jpg']
# ['02890', 'jpg']
# ['03556', 'jpg']
# ['02648', 'jpg']
# ['05127', 'jpg']
# ['01816', 'jpg']
# ['03967', 'jpg']
# ['03973', 'jpg']
# ['01802', 'jpg']
# ['07283', 'jpg']
# ['04952', 'jpg']
# ['05494', 'jpg']
# ['03783', 'jpg']
# ['01194', 'jpg']
# ['06823', 'jpg']
#  98%|█████████▊| 7980/8144 [01:43<00:02, 67.07it/s]['01180', 'jpg']
# ['06837', 'jpg']
# ['03797', 'jpg']
# ['02489', 'jpg']
# ['04946', 'jpg']
# ['05480', 'jpg']
# ['07297', 'jpg']
# ['06189', 'jpg']
# ['06162', 'jpg']
# ['00513', 'jpg']
# ['04775', 'jpg']
# ['02304', 'jpg']
# ['02462', 'jpg']
# ['04013', 'jpg']
# ['00275', 'jpg']
# ['06604', 'jpg']
# ['00261', 'jpg']
#  98%|█████████▊| 7997/8144 [01:44<00:02, 72.60it/s]['06610', 'jpg']
# ['05319', 'jpg']
# ['02476', 'jpg']
# ['03768', 'jpg']
# ['04007', 'jpg']
# ['04761', 'jpg']
# ['02310', 'jpg']
# ['06176', 'jpg']
# ['01619', 'jpg']
# ['00507', 'jpg']
# ['07268', 'jpg']
# ['04749', 'jpg']
# ['03026', 'jpg']
# ['02338', 'jpg']
# ['04991', 'jpg']
# ['05457', 'jpg']
# ['01631', 'jpg']
#  98%|█████████▊| 8015/8144 [01:44<00:01, 77.06it/s]['07240', 'jpg']
# ['07526', 'jpg']
# ['00249', 'jpg']
# ['01157', 'jpg']
# ['06638', 'jpg']
# ['03998', 'jpg']
# ['05331', 'jpg']
# ['03740', 'jpg']
# ['05325', 'jpg']
# ['03754', 'jpg']
# ['07532', 'jpg']
# ['01143', 'jpg']
# ['01625', 'jpg']
# ['07254', 'jpg']
# ['03032', 'jpg']
# ['04985', 'jpg']
#  99%|█████████▊| 8031/8144 [01:44<00:01, 75.89it/s]['05443', 'jpg']
# ['01962', 'jpg']
# ['03813', 'jpg']
# ['03807', 'jpg']
# ['01976', 'jpg']
# ['01786', 'jpg']
# ['00498', 'jpg']
# ['03191', 'jpg']
# ['04826', 'jpg']
# ['05286', 'jpg']
# ['04198', 'jpg']
# ['06957', 'jpg']
# ['07491', 'jpg']
# ['06943', 'jpg']
# ['07485', 'jpg']
# ['05292', 'jpg']
# ['03185', 'jpg']
#  99%|█████████▉| 8047/8144 [01:44<00:01, 67.64it/s]['04832', 'jpg']
# ['01792', 'jpg']
# ['07308', 'jpg']
# ['00467', 'jpg']
# ['01779', 'jpg']
# ['06016', 'jpg']
# ['02270', 'jpg']
# ['04601', 'jpg']
# ['04167', 'jpg']
# ['03608', 'jpg']
# ['02516', 'jpg']
# ['05279', 'jpg']
# ['06770', 'jpg']
# ['00301', 'jpg']
# ['06764', 'jpg']
# ['00315', 'jpg']
#  99%|█████████▉| 8063/8144 [01:45<00:01, 70.22it/s]['04173', 'jpg']
# ['02502', 'jpg']
# ['02264', 'jpg']
# ['04615', 'jpg']
# ['00473', 'jpg']
# ['06002', 'jpg']
# ['05523', 'jpg']
# ['03152', 'jpg']
# ['07334', 'jpg']
# ['08007', 'jpg']
# ['01745', 'jpg']
# ['01023', 'jpg']
# ['06994', 'jpg']
# ['07452', 'jpg']
# ['03634', 'jpg']
#  99%|█████████▉| 8072/8144 [01:45<00:00, 74.70it/s]['05245', 'jpg']
# ['03620', 'jpg']
# ['05251', 'jpg']
# ['06758', 'jpg']
# ['01037', 'jpg']
# ['06980', 'jpg']
# ['00329', 'jpg']
# ['07446', 'jpg']
# ['07320', 'jpg']
# ['08013', 'jpg']
# ['01989', 'jpg']
# ['01751', 'jpg']
# ['05537', 'jpg']
#  99%|█████████▉| 8089/8144 [01:45<00:00, 69.21it/s]['02258', 'jpg']
# ['03146', 'jpg']
# ['04629', 'jpg']
# ['07877', 'jpg']
# ['05906', 'jpg']
# ['05912', 'jpg']
# ['07863', 'jpg']
# ['07693', 'jpg']
# ['02933', 'jpg']
# ['05084', 'jpg']
# ['03393', 'jpg']
# ['00842', 'jpg']
# ['01584', 'jpg']
# ['00856', 'jpg']
# ['01590', 'jpg']
# 100%|█████████▉| 8105/8144 [01:45<00:00, 70.61it/s]['02099', 'jpg']
# ['03387', 'jpg']
# ['02927', 'jpg']
# ['05090', 'jpg']
# ['06599', 'jpg']
# ['07687', 'jpg']
# ['00103', 'jpg']
# ['06572', 'jpg']
# ['02714', 'jpg']
# ['04365', 'jpg']
# ['04403', 'jpg']
# ['02072', 'jpg']
# ['06214', 'jpg']
# ['00665', 'jpg']
# ['06200', 'jpg']
# ['00671', 'jpg']
# ['04417', 'jpg']
# 100%|█████████▉| 8122/8144 [01:45<00:00, 72.23it/s]['03378', 'jpg']
# ['02066', 'jpg']
# ['05709', 'jpg']
# ['02700', 'jpg']
# ['04371', 'jpg']
# ['07678', 'jpg']
# ['00117', 'jpg']
# ['01209', 'jpg']
# ['06566', 'jpg']
# ['05047', 'jpg']
# ['02728', 'jpg']
# ['03436', 'jpg']
# ['04359', 'jpg']
# ['07650', 'jpg']
# ['01221', 'jpg']
# ['07888', 'jpg']
# 100%|██████████| 8144/8144 [01:46<00:00, 76.71it/s]['00881', 'jpg']
# ['06228', 'jpg']
# ['01547', 'jpg']
# ['00659', 'jpg']
# ['07136', 'jpg']
# ['03350', 'jpg']
# ['05721', 'jpg']
# ['03344', 'jpg']
# ['05735', 'jpg']
# ['00895', 'jpg']
# ['01553', 'jpg']
# ['07122', 'jpg']
# ['07644', 'jpg']
# ['01235', 'jpg']
# ['05053', 'jpg']
# ['03422', 'jpg']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-87811481ddd8> in <module>
#       9     image = cv2.resize(image, (image_size,image_size))
#      10     image2.append([np.array(image), image_name])
# ---> 11 shuffle(train_data)
#      12 np.save('train.npy', train)
#      13 return train_data
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/random.py in shuffle(self, x, random)
#     302         if random is None:
#     303             randbelow = self._randbelow
# --> 304             for i in reversed(range(1, len(x))):
#     305                 # pick an element in x[:i+1] with which to exchange x[i]
#     306                 j = randbelow(i+1)
#
# TypeError: object of type 'NoneType' has no len()

# %%
train_data = create_train_data()
